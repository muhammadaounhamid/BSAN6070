# %% [markdown]
# # Your name: MUHAMMAD AOUN HAMID
# ## Assignment Name: CA01 - Data Cleaning and Exploration of India Air Quality

# %% [markdown]
# # Program Inititialization Section
# ## Enter your import packages here

# %%
# import packages 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Data File Reading Section
# ## Write code to read in data from external sources here

# %%
# read datasets

data = pd.read_csv('data.csv', encoding = "ISO-8859-1")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# first few rows of dataset

data.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# ...

# %% [markdown]
# # Initial Data Investigation Section
#
# ## Summarized details
# ### Generate descriptive statistics that summarize the central tendency, dispersion, and shape of a dataset’s distribution, excluding NaN values.
# #### Steps:
# #### 1. Statistical Description of data (data.describe)
# #### 2. Display number of total rows and columns of the dataset (data.shape)
# #### 3. Display number of non-null values for each column (data.count)
# #### 4. Display number of null values for each column (sum of data.isnull)
# #### 5. Display range, column, number of non-null objects of each column, datatype and memory usage (data.info)
# #### 6. Display Top 10 and Bottom 10 records (head and tail)

# %%
# STEP 1 statistical description of data

data.describe()
# Out:
#                  so2            no2           rspm            spm        pm2_5
# count  401096.000000  419509.000000  395520.000000  198355.000000  9314.000000
# mean       10.829414      25.809623     108.832784     220.783480    40.791467
# std        11.177187      18.503086      74.872430     151.395457    30.832525
# min         0.000000       0.000000       0.000000       0.000000     3.000000
# 25%         5.000000      14.000000      56.000000     111.000000    24.000000
# 50%         8.000000      22.000000      90.000000     187.000000    32.000000
# 75%        13.700000      32.200000     142.000000     296.000000    46.000000
# max       909.000000     876.000000    6307.033333    3380.000000   504.000000

# %%
# STEP 2 number of total rows and columns of the dataset

data.shape
# Out:
# (435742, 13)

# %%
# STEP 3 number of non-null values for each column

data.count()
# Out:
# stn_code                       291665
# sampling_date                  435739
# state                          435742
# location                       435739
# agency                         286261
# type                           430349
# so2                            401096
# no2                            419509
# rspm                           395520
# spm                            198355
# location_monitoring_station    408251
# pm2_5                            9314
# date                           435735
# dtype: int64

# %%
# STEP 4 number of null values for each column

data.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
# STEP 5 range, column, number of non-null objects of each column, datatype and memory usage 

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
# STEP 6(i) top 10 records of the dataset

data.head(10)
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 5    152.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 6    150.0     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 7    151.0     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 8    152.0     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 9    151.0       May - M051990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# ...

# %%
# STEP 6(ii) bottom 10 records of the dataset

data.tail(10)
# Out:
#        stn_code sampling_date                        state  location  \
# 435732     SAMP      09-12-15                  West Bengal  ULUBERIA
# 435733     SAMP      12-12-15                  West Bengal  ULUBERIA
# 435734     SAMP      15-12-15                  West Bengal  ULUBERIA
# 435735     SAMP      18-12-15                  West Bengal  ULUBERIA
# 435736     SAMP      21-12-15                  West Bengal  ULUBERIA
# 435737     SAMP      24-12-15                  West Bengal  ULUBERIA
# 435738     SAMP      29-12-15                  West Bengal  ULUBERIA
# 435739      NaN           NaN  andaman-and-nicobar-islands       NaN
# 435740      NaN           NaN                  Lakshadweep       NaN
# 435741      NaN           NaN                      Tripura       NaN
#
#                                            agency   type   so2   no2   rspm  \
# 435732  West Bengal State Pollution Control Board  RIRUO  22.0  50.0  145.0
# ...

# %% [markdown]
# ## Cleansing the dataset
# ### Dropping of less valued columns:
# 1. stn_code, agency, sampling_date, location_monitoring_agency do not add much value to the dataset in terms of information. Therefore, we can drop those columns.
#
# 2. Dropping rows where no date is available.

# %%
# Cleaning up the data

# dropping columns that aren't required

data = data.drop(['stn_code', 'sampling_date', 'agency', 'location_monitoring_station'], axis = 1)

# dropping rows where no date is available

data.dropna(subset = ['date'], inplace = True)

# %%
# displaying final columns (data.columns)

data.columns
# Out:
# Index(['state', 'location', 'type', 'so2', 'no2', 'rspm', 'spm', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
# displaying the top 5 records of the updated dataset 

data.head()
# Out:
#             state   location                                type  so2   no2  \
# 0  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  4.8  17.4
# 1  Andhra Pradesh  Hyderabad                     Industrial Area  3.1   7.0
# 2  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.2  28.5
# 3  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.3  14.7
# 4  Andhra Pradesh  Hyderabad                     Industrial Area  4.7   7.5
#
#    rspm  spm  pm2_5        date
# 0   NaN  NaN    NaN  1990-02-01
# 1   NaN  NaN    NaN  1990-02-01
# 2   NaN  NaN    NaN  1990-02-01
# 3   NaN  NaN    NaN  1990-03-01
# 4   NaN  NaN    NaN  1990-03-01

# %% [markdown]
# ### Changing the types to uniform format:
#
# Notice that the ‘type’ column has values such as ‘Industrial Area’ and ‘Industrial Areas’ — both actually mean the same, so let’s remove such type of stuff and make it uniform. Replace the 'type' values with standard codes as follows:
#
# types = {
#     "Residential": "R",
#     "Residential and others": "RO",
#     "Residential, Rural and other Areas": "RRO",
#     "Industrial Area": "I",
#     "Industrial Areas": "I",
#     "Industrial": "I",
#     "Sensitive Area": "S",
#     "Sensitive Areas": "S",
#     "Sensitive": "S",
#     np.nan: "RRO"
# }
#
# data.type = data.type.replace(types)

# %%
types = { "Residential": "R", "Residential and others": "RO", "Residential, Rural and other Areas": "RRO",
         "Industrial Area": "I", "Industrial Areas": "I", "Industrial": "I", "Sensitive Area": "S", "Sensitive Areas": "S",
         "Sensitive": "S", np.nan: "RRO" }

data.type = data.type.replace(types)

# %%
# Display top 10 records after codification of 'types'
data.head(10)
# Out:
#             state   location type  so2   no2  rspm  spm  pm2_5        date
# 0  Andhra Pradesh  Hyderabad  RRO  4.8  17.4   NaN  NaN    NaN  1990-02-01
# 1  Andhra Pradesh  Hyderabad    I  3.1   7.0   NaN  NaN    NaN  1990-02-01
# 2  Andhra Pradesh  Hyderabad  RRO  6.2  28.5   NaN  NaN    NaN  1990-02-01
# 3  Andhra Pradesh  Hyderabad  RRO  6.3  14.7   NaN  NaN    NaN  1990-03-01
# 4  Andhra Pradesh  Hyderabad    I  4.7   7.5   NaN  NaN    NaN  1990-03-01
# 5  Andhra Pradesh  Hyderabad  RRO  6.4  25.7   NaN  NaN    NaN  1990-03-01
# 6  Andhra Pradesh  Hyderabad  RRO  5.4  17.1   NaN  NaN    NaN  1990-04-01
# 7  Andhra Pradesh  Hyderabad    I  4.7   8.7   NaN  NaN    NaN  1990-04-01
# 8  Andhra Pradesh  Hyderabad  RRO  4.2  23.0   NaN  NaN    NaN  1990-04-01
# 9  Andhra Pradesh  Hyderabad    I  4.0   8.9   NaN  NaN    NaN  1990-05-01

# %% [markdown]
# ### Creating a year column
# To view the trend over a period of time, we need year values for each row and also when you see in most of the values in date column only has ‘year’ value. So, let’s create a new column holding year values. Convert the column to 'datetime' type and extract the year to populate the new column. Display Top 5 records after the conversion.

# %%
# 
data.date = pd.to_datetime(data.date)

#
type(data.date[1])

# 
data['year'] = pd.DatetimeIndex(data.date).year

# displaying top 5 records after conversion
data.head()
# Out:
#             state   location type  so2   no2  rspm  spm  pm2_5       date  \
# 0  Andhra Pradesh  Hyderabad  RRO  4.8  17.4   NaN  NaN    NaN 1990-02-01
# 1  Andhra Pradesh  Hyderabad    I  3.1   7.0   NaN  NaN    NaN 1990-02-01
# 2  Andhra Pradesh  Hyderabad  RRO  6.2  28.5   NaN  NaN    NaN 1990-02-01
# 3  Andhra Pradesh  Hyderabad  RRO  6.3  14.7   NaN  NaN    NaN 1990-03-01
# 4  Andhra Pradesh  Hyderabad    I  4.7   7.5   NaN  NaN    NaN 1990-03-01
#
#    year
# 0  1990
# 1  1990
# 2  1990
# 3  1990
# 4  1990

# %% [markdown]
# ### Handling Missing Values
#
# The column such as SO2, NO2, rspm, spm, pm2_5 are the ones which contribute much to our analysis. So, we need to remove null from those columns to avoid inaccuracy in the prediction.
# We use the Imputer from sklearn.preprocessing to fill the missing values in every column with the mean.

# %%
# define columns of importance, which shall be used reguarly (COLS = ....)
# invoke SimpleImputer to fill missing values using 'mean' as the replacement strategy
# Display data.info after the transformation
# Display that there are no more missing values in the dataset

from sklearn.impute import SimpleImputer
cols = 'so2', 'no2', 'rspm', 'spm', 'pm2_5'

imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
data[['so2', 'no2', 'rspm', 'spm', 'pm2_5']] = imputer.fit_transform(data[['so2', 'no2', 'rspm', 'spm', 'pm2_5']])

data.info()

data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435735 entries, 0 to 435738
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   state     435735 non-null  object
#  1   location  435735 non-null  object
#  2   type      435735 non-null  object
#  3   so2       435735 non-null  float64
#  4   no2       435735 non-null  float64
#  5   rspm      435735 non-null  float64
#  6   spm       435735 non-null  float64
#  7   pm2_5     435735 non-null  float64
#  8   date      435735 non-null  datetime64[ns]
#  9   year      435735 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(3)
# memory usage: 52.7+ MB
# state       0
# location    0
# type        0
# so2         0
# no2         0
# rspm        0
# spm         0
# pm2_5       0
# date        0
# year        0
# dtype: int64

# %% [markdown]
# ## Statewise Grouping of so2, no2, rspm, spm values
#
# Calculate median values of so2, no2, rspm, spm for each state and display in (a) as table (b) bar chart, with values sorted in ascending order. Separate section for each of the component. Use matplotlib().

# %% [markdown]
# ### so2 status

# %%
# median values of so2 for each state as table (a)
so2_median = data.groupby(['state']).median().so2.sort_values()
print(so2_median)
# Out:
# state
# Nagaland                 2.000000
# Mizoram                  2.000000
# Meghalaya                2.000000
# Arunachal Pradesh        2.500000
# Himachal Pradesh         3.000000
# Kerala                   4.200000
# Telangana                5.000000
# Odisha                   5.000000
# Jammu & Kashmir          5.000000
# Andhra Pradesh           5.000000
# Goa                      6.000000
# Rajasthan                6.300000
# Delhi                    6.300000
# Assam                    6.500000
# Puducherry               7.266667
# Daman & Diu              7.600000
# Chandigarh               7.950000
# West Bengal              8.000000
# Dadra & Nagar Haveli     8.400000
# Karnataka               10.000000
# Uttar Pradesh           10.000000
# Tamil Nadu              10.000000
# Punjab                  10.300000
# Manipur                 10.829428
# Bihar                   10.829428
# Haryana                 10.829428
# Madhya Pradesh          10.829428
# ...

# %%
# median values of so2 for each state as bar chart (b)
so2_median.plot.bar(xlabel = 'state', ylabel = 'so2 level' , color = 'r', figsize = (8,4))
# Out:
# <AxesSubplot:xlabel='state', ylabel='so2 level'>

# %% [markdown]
# ### no2 status

# %%
# median values of no2 for each state as table (a)
no2_median = data.groupby(['state']).median().no2.sort_values()
print(no2_median)
# Out:
# state
# Arunachal Pradesh        5.000000
# Mizoram                  5.000000
# Nagaland                 7.000000
# Meghalaya               10.000000
# Goa                     11.600000
# Puducherry              13.000000
# Jammu & Kashmir         13.000000
# Himachal Pradesh        13.900000
# Kerala                  14.000000
# Assam                   14.000000
# Odisha                  16.000000
# Daman & Diu             17.600000
# Chandigarh              18.000000
# Dadra & Nagar Haveli    18.000000
# Madhya Pradesh          19.200000
# Manipur                 19.800000
# Andhra Pradesh          20.000000
# Tamil Nadu              21.000000
# Karnataka               21.200000
# Chhattisgarh            21.500000
# Telangana               22.000000
# Haryana                 22.750000
# Gujarat                 23.000000
# Uttarakhand             25.809659
# Rajasthan               26.000000
# Sikkim                  26.800000
# Uttar Pradesh           27.000000
# ...

# %%
# median values of no2 for each state as bar chart (b)
no2_median.plot.bar(xlabel = 'state', ylabel = 'no2 median level', color = 'r', figsize = (8,4))
# Out:
# <AxesSubplot:xlabel='state', ylabel='no2 median level'>

# %% [markdown]
# ### rspm status

# %%
# median values of rspm for each state as table (a)
rspm_median = data.groupby(['state']).median().rspm.sort_values()
print(rspm_median)
# Out:
# state
# Sikkim                   32.000000
# Mizoram                  40.000000
# Puducherry               46.000000
# Kerala                   49.000000
# Goa                      56.000000
# Meghalaya                57.000000
# Tamil Nadu               59.000000
# Manipur                  61.000000
# Karnataka                63.000000
# Arunachal Pradesh        74.500000
# Andhra Pradesh           76.000000
# Assam                    77.000000
# Nagaland                 78.000000
# Telangana                80.000000
# Odisha                   81.000000
# Himachal Pradesh         90.000000
# Chandigarh               90.000000
# Dadra & Nagar Haveli     91.000000
# Gujarat                  95.000000
# West Bengal              96.000000
# Maharashtra              96.000000
# Chhattisgarh            108.833091
# Madhya Pradesh          108.833091
# Bihar                   108.833091
# Daman & Diu             108.833091
# Uttaranchal             112.000000
# ...

# %%
# median values of rspm for each state as bar chart (b)
rspm_median.plot.bar(xlabel = 'state', ylabel = 'rspm median level', color = 'r', figsize = (8,4))
# Out:
# <AxesSubplot:xlabel='state', ylabel='rspm median level'>

# %% [markdown]
# ### spm status

# %%
# median values of spm for each state as table (a)
spm_median = data.groupby(['state']).median().spm.sort_values()
print(spm_median)
# Out:
# state
# Sikkim                   75.00000
# Manipur                 120.50000
# Puducherry              191.00000
# Goa                     199.00000
# Daman & Diu             200.50000
# Andhra Pradesh          220.78348
# Meghalaya               220.78348
# Mizoram                 220.78348
# Nagaland                220.78348
# Odisha                  220.78348
# Punjab                  220.78348
# Tamil Nadu              220.78348
# Telangana               220.78348
# Uttar Pradesh           220.78348
# Uttarakhand             220.78348
# Rajasthan               220.78348
# Maharashtra             220.78348
# Kerala                  220.78348
# Karnataka               220.78348
# Jharkhand               220.78348
# Jammu & Kashmir         220.78348
# Himachal Pradesh        220.78348
# Haryana                 220.78348
# Gujarat                 220.78348
# Dadra & Nagar Haveli    220.78348
# Chhattisgarh            220.78348
# Chandigarh              220.78348
# ...

# %%
# median values of spm for each state as bar chart (b)
spm_median.plot.bar(xlabel = 'state', ylabel = 'spm median level', color = 'r', figsize = (8,4))
# Out:
# <AxesSubplot:xlabel='state', ylabel='spm median level'>

# %% [markdown]
# ### What is the yearly trend in a particular state, say ‘Andhra Pradesh’?
#
# Create a new dataframe containing the NO2, SO2, rspm, and spm data regarding state ‘Andhra Pradesh’ only and group it by ‘year’. Display top 5 records after.

# %%
new_data = data.loc[data.state == 'Andhra Pradesh', ['state', 'no2', 'so2', 'rspm', 'spm', 'year']]

new_data_year = new_data.groupby(['year']).median().sort_values('year')

new_data_year.head()
# Out:
#        no2    so2        rspm        spm
# year
# 1990  13.6   5.60  108.833091  179.00000
# 1991  12.8   8.25  108.833091  141.50000
# 1992  27.6  12.40  108.833091  192.00000
# 1993  11.4   6.00  108.833091  220.78348
# 1994  14.2   8.70  108.833091  220.78348

# %%
# Display yearly trend graph (year vs. value) in pairs: (a) so2 and no2 (b) rspm and spm. 
# So, you will display TWO graphs altogether.

plt.figure(figsize = (20,10))
plt.subplot(221)
plt.plot(new_data_year['no2'], linestyle = 'dashed', marker = 'o', color = 'r', label = 'Total no2 Levels')
plt.plot(new_data_year['so2'], linestyle = 'dotted', marker = 'x', color = 'b', label = 'Total so2 Levels')
plt.title('Andhra Pradesh Yearly so2 and no2 levels each year')
plt.xlabel('Year')
plt.legend()
plt.show

plt.subplot(222)
plt.plot(new_data_year['rspm'], linestyle = 'dashed', marker = 'o', color = 'r', label = 'Total rspm Levels')
plt.plot(new_data_year['spm'], linestyle = 'dotted', marker = 'x', color ='b', label = 'Total spm Levels')
plt.title('Andhra Pradesh rspm and spm levels each year')
plt.xlabel('Year')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Do you find anything alarming? Explain what you can conclude from this Exploratory Data Analysis for the State of Andhra Pradesh. Enter your answer here .....

# %% [markdown]
# ### after analyzing the India Air Quality dataset we can see that there is a steady decline in rspm levels over the years and so2 levels in recent years from 2004 and beyond.
